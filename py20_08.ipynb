# %% [markdown]
# <a href="https://colab.research.google.com/github/anushkadas06/my-python-project/blob/main/py20_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t = (10, 20, 30, 40)
print(t)
# Out:
# (10, 20, 30, 40)

# %%
mytuple = (10, 2.15, "Anushka", True, [1,2,3])
print("Tuple:", mytuple)
# Out:
# Tuple: (10, 2.15, 'Anushka', True, [1, 2, 3])

# %%
x = ([23,41,55])
print(x[1])
# Out:
# 41

# %%
t = (10, 20, 30)

a, b, c = t

print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %%
t = (10, 20, 30, 40, 50, 60, 70)

print(t[-4])
# Out:
# 40

# %%
t = (10, 20, 35, 66, 40, 10, 66)

for item in set(t):
    if t.count(item) > 1:
        print(item)
# Out:
# 66
# 10

# %%
mytuple = ("Anushka", 20, "CSE")
name, age, department = mytuple
print("Name:", name)
print("Age:", age)
print("Department:", department)
# Out:
# Name: Anushka
# Age: 20
# Department: CSE

# %%
mytuple = (10, 20, 30, 40, 50, 60, 70, 80)

fourth_from_last = mytuple[-4]

print("The 4th element from the last is:", fourth_from_last)
# Out:
# The 4th element from the last is: 50

# %%
t = (10, 20, 30, 40)

lst = list(t)
lst.remove(30)

t = tuple(lst)

print(t)
# Out:
# (10, 20, 40)

# %%
t = (10, 20, 30, 40, 50, 60)

print(t[1:4])
# Out:
# (20, 30, 40)

# %%
t = (10, 20, 30, 40, 50)

print(len(t))
# Out:
# 5

# %%
t = (10, 20, 30, 40, 50)

reversed_tuple = t[::-1]

print(reversed_tuple)
# Out:
# (50, 40, 30, 20, 10)

# %%
lst = [("a", 1), ("b", 2), ("c", 3)]

d = dict(lst)

print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3}
