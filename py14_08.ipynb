# %% [markdown]
# <a href="https://colab.research.google.com/github/anushkadas06/my-python-project/blob/main/py14_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = [10, 20, 30, 20, 40, 50, 20, 60, 70, 80]

print("List:", numbers)
print("Length:", len(numbers))
print("Maximum:", max(numbers))
print("Minimum:", min(numbers))

total = 0
for num in numbers:
    total += num

print("Sum:", total)

average = total / len(numbers)
print("Average:", average)

mean = total / len(numbers)
print("Mean:", mean)

sorted_list = numbers.copy()

for i in range(len(sorted_list)):
    for j in range(i + 1, len(sorted_list)):
        if sorted_list[i] > sorted_list[j]:
            sorted_list[i], sorted_list[j] = sorted_list[j], sorted_list[i]

n = len(sorted_list)

if n % 2 == 0:
    median = (sorted_list[n // 2 - 1] + sorted_list[n // 2]) / 2
else:
    median = sorted_list[n // 2]

print("Median:", median)

max_count = 0
mode = numbers[0]

for num in numbers:
    count = 0

    for x in numbers:
        if x == num:
            count += 1

    if count > max_count:
        max_count = count
        mode = num

print("Mode:", mode)
# Out:
# List: [10, 20, 30, 20, 40, 50, 20, 60, 70, 80]
# Length: 10
# Maximum: 80
# Minimum: 10
# Sum: 400
# Average: 40.0
# Mean: 40.0
# Median: 35.0
# Mode: 20

# %%
students = ["Anushka", "Anurupa", "Ankita", "Aditi", "Asmita"]

print("Original list:", students)

students.append("Rifat")

students.insert(2, "Priyanka")

students.remove("Aditi")

print("Final list:", students)
# Out:
# Original list: ['Anushka', 'Anurupa', 'Ankita', 'Aditi', 'Asmita']
# Final list: ['Anushka', 'Anurupa', 'Priyanka', 'Ankita', 'Asmita', 'Rifat']

# %%
numbers = [12, 23, 34, 45, 56, 67, 78]

new_list = []

for num in numbers:
    if num not in new_list:
        new_list.append(num)

print("Original list:", numbers)
print("List without duplicates:", new_list)
# Out:
# Original list: [12, 23, 34, 45, 56, 67, 78]
# List without duplicates: [12, 23, 34, 45, 56, 67, 78]

# %%
numbers = [12, 23, 34, 45, 56, 67, 78, 56, 91]

new_list = []

for num in numbers:
    if num not in new_list:
        new_list.append(num)

print("Original list:", numbers)
print("List without duplicates:", new_list)
# Out:
# Original list: [12, 23, 34, 45, 56, 67, 78, 56, 91]
# List without duplicates: [12, 23, 34, 45, 56, 67, 78, 91]

# %%
numbers = [10, 20, 30, 40, 50]

reversed_list = []

for i in range(len(numbers) - 1, -1, -1):
    reversed_list.append(numbers[i])

print("Original list:", numbers)
print("Reversed list:", reversed_list)
# Out:
# Original list: [10, 20, 30, 40, 50]
# Reversed list: [50, 40, 30, 20, 10]

# %%
numbers= [12, 13, 23, 54, 67, 32, 13, 81]
element = int(input("Enter the element to find:"))

count=0
for num in numbers:
    if num == element:
        count += 1

print("Frequency of", element, "is:", count)
# Out:
# Enter the element to find:13
# Frequency of 13 is: 2
