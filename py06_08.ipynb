# %% [markdown]
# <a href="https://colab.research.google.com/github/anushkadas06/my-python-project/blob/main/py06_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def display():
  print("Hello")

print("Begin")
display()
print("End")
# Out:
# Begin
# Hello
# End

# %%
def addition(x,y):
  result=x+y
  print("Result=", result)
a= int(input("enter a="))
b= int(input("enter b="))
addition(a,b)
# Out:
# enter a=10
# enter b=20
# Result= 30

# %%
def addition(x,y):
  return x+y
  print("Result=", result)
a= int(input("enter a="))
b= int(input("enter b="))
result=addition(a,b)
print("Result=", +result)
# Out:
# enter a=20
# enter b=30
# Result= 50

# %%
def addition(x,y):
 return x+y

def substraction(x,y):
 return x-y

def multiplication(x,y):
 return x*y

def division(x,y):
 return x/y

print("1.Addition")
print("2.Substraction")
print("3.Multiplication")
print("4.Division")
a=int(input("Enter a number="))
b=int(input("Enter a number="))
choice=int(input("Enter your choice="))

if choice==1:
  result=addition(a,b)
  print(result)

if choice==2:
  result=substraction(a,b)
  print(result)

if choice==3:
  result=multiplication(a,b)
  print(result)

if choice==4:
  result=division(a,b)
  print(result)
# Out:
# 1.Addition
# 2.Substraction
# 3.Multiplication
# 4.Division
# Enter a number=20
# Enter a number=7
# Enter your choice=3
# 140

# %%
def si(p, r, t):
    si = (p * r * t) / 100
    print("Simple Interest is:", si)

p = float(input("Enter Principal amount: "))
r = float(input("Enter Rate of interest: "))
t = float(input("Enter Time in years: "))

si(p, r, t)
# Out:
# Enter Principal amount: 3000
# Enter Rate of interest: 12
# Enter Time in years: 2
# Simple Interest is: 720.0

# %%
num = int(input("Enter a number: "))

fact = 1
i = 1

while i <= num:
    fact = fact * i
    i = i + 1

print("Factorial of the number is:", fact)
# Out:
# Enter a number: 6
# Factorial of the number is: 720

# %%
basic = float(input("Enter Basic Salary: "))
da = float(input("Enter DA: "))
hra = float(input("Enter HRA: "))

total_salary = basic + da + hra

if total_salary > 100000:
    tax = total_salary * 0.30
elif total_salary > 80000:
    tax = total_salary * 0.10
else:
    tax = 0

gross_salary = total_salary - tax

print("Gross Salary is:", gross_salary)
# Out:
# Enter Basic Salary: 60000
# Enter DA: 15000
# Enter HRA: 12000
# Gross Salary is: 78300.0

# %%
def addition(x,y):
  return x+y

def subtraction(x,y):
  return x-y

def multiplication(x,y):
  return x*y

def division(x,y):
  return x/y

while True:
  print("1.Addition")
  print("2.Subtraction")
  print("3.Multiplication")
  print("4.Division")
  print("5.Exit")

a=int(input("Enter a number"))
b=int(input("Enter a number"))
choice=int(input("Enter your choice="))

if choice==1:
  result=addition(a,b)
  print(result)

if choice==2:
  result=subtraction(a,b)
  print(result)

if choice==3:
 result=multiplication(a,b)
 print(result)

if choice==4:
  result=division(a,b)
  print(result)
